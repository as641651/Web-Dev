# %% [markdown]
# ## Table

# %% [markdown]
# ```html
#
# <html>
#   <head>
#     <title> My WebPage </title>
#   </head>
#   <body>
#
#     <!-- In CCS Section we ll see the styles -->
#     <table>
#
#       <!-- Table header (AUTOMATICALLY BOLD)-->
#       <thead>
#         <tr>
#           <!-- Column names -->
#           <th>Name</th>
#           <th>Favourite<br /> Color</th>
#         </tr>
#       </thead>
#
#       <!-- Table Body -->
#       <tbody>
#         <!-- Table row -->
#         <tr>
#           <!--Tabel cell -->
#           <td><strong>Rob</strong></td>
#           <td>Green</td>
#         </tr>
#
#         <tr>
#           <td><strong>Tommy</strong></td>
#           <td>Orange</td>
#         </tr>
#
#         <tr>
#           <td><strong>Kristen</strong></td>
#           <td>Yellow</td>
#         </tr>
#
#      </tbody>
#
#     </table>
#
#   </body>
# </html>
#
# ```

# %% [markdown]
# ### Output :
#
# <div class="alert alert-block alert-info">
#
# <html>
#   <head>
#     <title> My WebPage </title>
#   </head>
#   <body>
#
#    <!-- In CCS Section we ll see the styles -->
#     <table>
#
#       <!-- Table header (AUTOMATICALLY BOLD)-->
#       <thead>
#         <tr>
#           <!-- Column names -->
#           <th>Name</th>
#           <th>Favourite<br /> Color</th>
#         </tr>
#       </thead>
#
#       <!-- Table Body -->
#       <tbody>
#         <!-- Table row -->
#         <tr>
#           <!--Tabel cell -->
#           <td><strong>Rob</strong></td>
#           <td>Green</td>
#         </tr>
#
#         <tr>
#           <td><strong>Tommy</strong></td>
#           <td>Orange</td>
#         </tr>
#
#         <tr>
#           <td><strong>Kristen</strong></td>
#           <td>Yellow</td>
#         </tr>
#
#      </tbody>
#
#     </table>
#
#   </body>
# </html>
#
# </div>
